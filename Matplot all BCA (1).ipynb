# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x=np.array([0,20,10,8])
y=np.array([0,40,20,45])
plt.scatter(x,y, color="g", marker="o")

# %%
x=np.array([0,20,10,8])
y=np.array([0,12,22,45])
plt.subplot(1,2,1)
plt.plot(x, color='r', marker='*', linestyle='dotted',linewidth=2, markersize=12,mec="g",mfc="w")
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)
x=np.array([0,20,10,8])
y=np.array([0,22,62,25])
plt.subplot(1,2,2)
plt.plot(y,c="b",marker="_",mec="g",lw=5)
plt.grid(color = 'green', linestyle = '--', linewidth = 0.5,axis='x')

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(2, 3, 2)
plt.plot(x,y)


x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(2, 3, 5)
plt.plot(x,y, c="r")

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(2, 3, 6)
plt.plot(x,y, c="g")
plt.suptitle("Sales of Cars")
# Out:
# Text(0.5, 0.98, 'Sales of Cars')

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
col=np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=col)

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, cmap = 'viridis',s=0.2)
plt.colorbar()
plt.show()
# Out:
# C:\Users\erzub\AppData\Local\Temp\ipykernel_24740\3409885674.py:12: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x, y, cmap = 'viridis',s=0.2)

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
col=np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])
plt.scatter(x, y, c=col , cmap = 'viridis',s=150, alpha=.5)
plt.colorbar()
plt.show()
# Out:
# C:\Users\erzub\AppData\Local\Temp\ipykernel_24740\2015547218.py:7: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   plt.scatter(x, y, c=col , cmap = 'viridis',s=150, alpha=.5)

# %%
x=np.array(["apple","orange","banana","papaya"])
y=np.array([120,43,111,76])
col=np.array(["r","b","g","r"])
plt.bar(x,y,color=col,width=0.5)
# Out:
# <BarContainer object of 4 artists>

# %%
x=np.array(["apple","orange","banana","papaya"])
y=np.array([120,43,111,76])
col=np.array(["r","b","g","r"])
plt.barh(x,y,color=col,height=0.5)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
x=np.random.normal(100,100,170)

# %%
plt.hist(x)
# Out:
# (array([ 3.,  8., 22., 21., 29., 43., 21., 13.,  7.,  3.]),
#  array([-146.29820415,  -96.97598366,  -47.65376316,    1.66845733,
#           50.99067783,  100.31289832,  149.63511882,  198.95733931,
#          248.27955981,  297.6017803 ,  346.9240008 ]),
#  <BarContainer object of 10 artists>)

# %%
x=np.array([3,6,8,2,9,7])
Labels= ["apple","orange","banana","papaya","Pine apple","Grapes"]
Explode=[0.3,0,0,0.5,0,0]
plt.pie(x, labels=Labels,explode=Explode,shadow=True)
plt.legend(title="fruits")

# %%
x=np.array([3,6,8,2,9,7])
plt.pie(x)
# Out:
# ([<matplotlib.patches.Wedge at 0x16b90162660>,
# ...
#  [Text(1.0603591446126612, 0.292640537923756, ''),
#   Text(0.5212555002170877, 0.9686551003806432, ''),
#   Text(-0.7601689521690987, 0.7950743136073097, ''),
#   Text(-1.0955717181523603, -0.09860329804162499, ''),
#   Text(-0.5212554321980598, -0.9686551369832372, ''),
#   Text(0.8899187936962865, -0.6465636400433808, '')])
